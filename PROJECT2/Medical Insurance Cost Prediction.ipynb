# %%
#importing basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# IMPORTING THE DATASET

# %%
#Reading the data set saved in the jupyter notebook, which is in tab seperated values format(\t)
df = pd.read_csv("Medical Insurance Cost.csv",sep = '\t')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# THERE ARE 1338 ROWS AND 7 COLUMNS OF DATA, WHICH INCLUDES OUR TARGET CAHRGES ALSO

# %%
#getting the head and last 5 rows of the data set
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %% [markdown]
# GETTING INFORMATION ABOUT THE DATA SET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# checking for the missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# IT SHOWS THAT ALL 7 COLUMNS HAS NO NULL VALUES

# %% [markdown]
# CHECKING THE MISSING VALUES IN THE DATASET THROUGH HEAT MAP

# %%
#to check missing values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# IT SHOWS THAT ALL 7 COLUMNS HAS NO NULL VALUES

# %%
#checking the column names of the dataset
print(df.columns)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# CHECKING THE UNIQUE VALUES PRESENT IN EACH COLUMN

# %%
df.age.unique()
# Out:
# array([19, 18, 28, 33, 32, 31, 46, 37, 60, 25, 62, 23, 56, 27, 52, 30, 34,
#        59, 63, 55, 22, 26, 35, 24, 41, 38, 36, 21, 48, 40, 58, 53, 43, 64,
#        20, 61, 44, 57, 29, 45, 54, 49, 47, 51, 42, 50, 39], dtype=int64)

# %% [markdown]
# CECKING THE NO OF OBSERVATIONS PRESENT IN EACH AGE

# %%
#checking the values in the quality column(target column)
df.age.value_counts()
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %% [markdown]
# MINIMUM AGE IS 18 AND MAXIMUM AGE IS 64
#
# AGE OF 18 &19 HAVING MOST DATA WHEN COMPARED TO OTHER AGES
#
# THERE IS LONG LIST OF UNIQUE AGE VALUES, SO WILL TRY EACH COLUMN'S NUMBER OF UNIQUE VALUES FIRST

# %%
#Checking the number of unique values present in each column

for i in range(len(df.columns)):
    print(df.columns[i],'=',df[df.columns[i]].nunique())
# Out:
# age = 47
# sex = 2
# bmi = 548
# children = 6
# smoker = 2
# region = 4
# charges = 1337

# %%
#Checking the unique values present in the each categorical column
col = ['sex','children', 'smoker', 'region']
for i in range(len(col)):
    print(col[i],'=',df[col[i]].unique())
# Out:
# sex = ['female' 'male']
# children = [0 1 3 2 5 4]
# smoker = ['yes' 'no']
# region = ['southwest' 'southeast' 'northwest' 'northeast']

# %% [markdown]
# GETTING THE STATISTICAL INFORMATION ABOUT THE DATASET

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# TO CHECK THE CORRELATION

# %%
# to check correlation
dfcor=df.corr()
dfcor
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %% [markdown]
# TO CHECK THE CORRELATION FOR SEX, REGION AND SMOKING STATUS WE NEED TO CONVERT THEM TO CATEGORICAL DATA IN 0,1,2 etc

# %%
#transforming/encoding sex column
df.replace({'sex':{'male':0,'female':1}},inplace=True)

#transforming/encoding smoker column
df.replace({'smoker':{'yes':1,'no':0}},inplace=True)

#transforming/encoding region column
df.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}},inplace=True)

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       1  16884.92400
# 1   18    0  33.770         1       0       0   1725.55230
# 2   28    0  33.000         3       0       0   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %% [markdown]
# NOW THE DATA IN THE SEX, SMOKER, REGION ARE CHANGED TO INT AS ABOVE

# %%
# to check correlation
dfcor=df.corr()
dfcor
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000  0.020856  0.109272  0.042469 -0.025019  0.005212  0.299008
# sex       0.020856  1.000000 -0.046371 -0.017163 -0.076185  0.016121 -0.057292
# bmi       0.109272 -0.046371  1.000000  0.012759  0.003750 -0.261829  0.198341
# children  0.042469 -0.017163  0.012759  1.000000  0.007673  0.019257  0.067998
# smoker   -0.025019 -0.076185  0.003750  0.007673  1.000000 -0.053930  0.787251
# region    0.005212  0.016121 -0.261829  0.019257 -0.053930  1.000000 -0.056993
# charges   0.299008 -0.057292  0.198341  0.067998  0.787251 -0.056993  1.000000

# %% [markdown]
# TO GET THE CORRELATION IN HEATMAP

# %%
#PLotting heat map to visualise the correlation
plt.figure(figsize=(10,8))
sns.heatmap(dfcor,cmap='Blues', annot=True, linewidth=.3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# IT SHOWS THAT BMI,SMOKER AND AGE HAS HIGH CORRELATION WITH CHARGES

# %%
#getting the correlation of the cherges column with the other columns
dfcor['charges']
# Out:
# age         0.299008
# sex        -0.057292
# bmi         0.198341
# children    0.067998
# smoker      0.787251
# region     -0.056993
# charges     1.000000
# Name: charges, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.title('Smoker vs Charges')
sns.scatterplot(df['smoker'],df['charges'],hue=df['smoker'])
plt.show()

# %% [markdown]
# THIS SHOWS THAT SMOKERS HAVE HIGH CHARGES OF INSURANCE

# %%
plt.figure(figsize=(10,5))
plt.title('Age vs Charges')
sns.scatterplot(df['age'],df['charges'],hue=df['age'])
plt.show()

# %% [markdown]
# THIS SHOWS THAT WITH INCREASE IN AGE CHARGES ARE INCREASING

# %%
plt.figure(figsize=(10,5))
plt.title('BMI vs Charges')
sns.scatterplot(df['bmi'],df['charges'],hue=df['bmi'])
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('BMI vs Charges')
sns.barplot(df['bmi'],df['charges'],data=df)
plt.show()

# %% [markdown]
# WITH INCREASE IN BMI CHARGES ARE INCREASING

# %%
plt.figure(figsize=(10,5))
plt.title('Children vs Charges')
sns.barplot(df['children'],df['charges'],data=df)
plt.show()

# %% [markdown]
# THERE IS NO EXACT RELATION BETWEEEN CHILDREN AND CHARGES

# %%
plt.figure(figsize=(10,5))
plt.title('Region vs Charges')
sns.barplot(df['region'],df['charges'],data=df)
plt.show()

# %% [markdown]
# REGION IS ALSO DONT HAVE EXACT RELATION WITH CHARGES, ALMOST EQUAL AT ALL REGIONS

# %%
plt.figure(figsize=(10,5))
plt.title('Sex vs Charges')
sns.barplot(df['sex'],df['charges'],data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,10))
df.corr()['charges'].sort_values(ascending=False).plot(kind='bar',color='g')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Column with target name',fontsize=14)
plt.title('Correlation',fontsize=18)
plt.show()

# %% [markdown]
# IT SHOWS THAT THE AGE, BMI, SMOKER ARE HIGHLY INFLUENCING THE CHARGES WHEN COMPARED To OTHERS

# %% [markdown]
# LETS CHECK THE OUTLIERS IN THE DATA WITH BOXPLOTS

# %%
df.plot(kind='box',subplots=True,layout=(1,7))
# Out:
# age            AxesSubplot(0.125,0.125;0.0945122x0.755)
# sex         AxesSubplot(0.238415,0.125;0.0945122x0.755)
# bmi         AxesSubplot(0.351829,0.125;0.0945122x0.755)
# children    AxesSubplot(0.465244,0.125;0.0945122x0.755)
# smoker      AxesSubplot(0.578659,0.125;0.0945122x0.755)
# region      AxesSubplot(0.692073,0.125;0.0945122x0.755)
# charges     AxesSubplot(0.805488,0.125;0.0945122x0.755)
# dtype: object

# %% [markdown]
# THERE ARE OUTLIERS IN BMI OF THE FEATURE COLUMNS

# %%
plt.figure(figsize=(15,12))
for i in enumerate(df.columns):
    plt.subplot(4,3,i[0]+1)
    sns.boxplot(df[i[1]])

# %%
#to check the distribution of the data of each column

plt.figure(figsize=(20,20))
for i in enumerate(df.columns):
    plt.subplot(4,3,i[0]+1)
    sns.distplot(df[i[1]])

# %% [markdown]
# Now we have to remove the outliers for removing the skewness from the dataset

# %% [markdown]
# ZSCORE METHOD

# %%
from scipy.stats import zscore

# to get the zscore
z=np.abs(zscore(df))

# %%
z
# Out:
#            age       sex       bmi  children    smoker    region   charges
# 0     1.438764  1.010519  0.453320  0.908614  1.970587  0.403289  0.298584
# 1     1.509965  0.989591  0.509621  0.078767  0.507463  1.287881  0.953689
# 2     0.797954  0.989591  0.383307  1.580926  0.507463  1.287881  0.728675
# 3     0.441948  0.989591  1.305531  0.908614  0.507463  1.365894  0.719843
# 4     0.513149  0.989591  0.292556  0.908614  0.507463  1.365894  0.776802
# ...        ...       ...       ...       ...       ...       ...       ...
# 1333  0.768473  0.989591  0.050297  1.580926  0.507463  1.365894  0.220551
# 1334  1.509965  1.010519  0.206139  0.908614  0.507463  0.481303  0.914002
# 1335  1.509965  1.010519  1.014878  0.908614  0.507463  1.287881  0.961596
# 1336  1.296362  1.010519  0.797813  0.908614  0.507463  0.403289  0.930362
# 1337  1.551686  1.010519  0.261388  0.908614  1.970587  1.365894  1.311053
#
# [1338 rows x 7 columns]

# %%
#checking the zscore values greater than 3
threshold=3
print(np.where(z>3))
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#         640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#        1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64), array([3, 6, 3, 2, 3, 3, 3, 3, 6, 3, 6, 3, 6, 2, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 6, 6, 3, 3, 6, 2], dtype=int64))

# %%
#randomly checking the zscore
z.loc[32][3]
# Out:
# 3.240618711442044

# %%
#randomly checking the zscore
z.loc[1317][2]
# Out:
# 3.685522232281654

# %% [markdown]
# ZSCORE INDEXES PRODUCED ABOVE ARE MORE THAN 3, AS WE CHECKED ABOVE

# %%
#checking the shape of the dataset before removing outliers
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# REMOVING OUTLIERS FROM THE DATSET ON THE BASIS OF ZSCORE

# %%
#Removing the outliers data
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (1309, 7)

# %% [markdown]
# 29 rows removed from the dataset

# %% [markdown]
# NOW CHECK THE IQR METHOD FOR REMOVAL OF OUTLIERS

# %%
from scipy import stats
IQR = stats.iqr(df)
IQR
# Out:
# 36.0

# %%
Q1 = df.quantile(0.25)
Q3 =  df.quantile(0.75)

# %%
#removing the outliers with IQR Method
df2 = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df2.shape
# Out:
# (675, 7)

# %% [markdown]
# THERE ARE MORE THAN 600 rows of DATA WAS REMOVED IN IQR METHOD, SO WE WILL OPT FOR ZSCORE METHOD AS THERE IS ONLY FEW DATA LOSS

# %% [markdown]
# NOW WE WILL TAKE THE DF1 DATASET OBTAINED FROM ZSCORE METHOD OF REMOVAL, FOR FURTHER PROCESS

# %%
#to check the skewness
plt.figure(figsize=(25,20))
for i in enumerate(df1.columns):
    plt.subplot(3,4,i[0]+1)
    sns.distplot(df[i[1]])

# %%
df.skew()
# Out:
# age         0.055673
# sex         0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region      0.048975
# charges     1.515880
# dtype: float64

# %%
df1.skew()
# Out:
# age         0.051340
# sex         0.010708
# bmi         0.191432
# children    0.738119
# smoker      1.482731
# region      0.033036
# charges     1.437160
# dtype: float64

# %%
df1.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    1  27.900         0       1       1  16884.92400
# 1   18    0  33.770         1       0       0   1725.55230
# 2   28    0  33.000         3       0       0   4449.46200
# 3   33    0  22.705         0       0       3  21984.47061
# 4   32    0  28.880         0       0       3   3866.85520

# %% [markdown]
# # Splitting the dataset into target and feature/input

# %%
from sklearn.model_selection import train_test_split

# %%
#Splitting the data set for features and target

x = df1.iloc[:,0:-1]
y = df1.iloc[:,-1]

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    0  33.770         1       0       0
# 2      28    0  33.000         3       0       0
# 3      33    0  22.705         0       0       3
# 4      32    0  28.880         0       0       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       3
# 1334   18    1  31.920         0       0       2
# 1335   18    1  36.850         0       0       0
# 1336   21    1  25.800         0       0       1
# 1337   61    1  29.070         0       1       3
#
# [1309 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1309, dtype: float64

# %%
x.shape
# Out:
# (1309, 6)

# %%
y.shape
# Out:
# (1309,)

# %% [markdown]
# As our data is in continuos type we have to use  Regression model

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (981, 6)

# %%
x_test.shape
# Out:
# (328, 6)

# %%
y_train.shape
# Out:
# (981,)

# %%
y_test.shape
# Out:
# (328,)

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
# Out:
# [  256.17002174    91.54014987   321.32702682   545.99771255
#  23164.41995423   278.54661192]

# %%
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))

pred_train=lr.predict(x_train)
# Out:
# 0.7755982423704892

# %%
plt.figure(figsize=(15,8))
plt.scatter(y_test,lr_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.show()

# %% [markdown]
# CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for i in range(2,20):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the cv score is {cv_mean} and accuracy score for traing is {Train_accuracy} and accuracy for the tsting is {Test_accuracy}")
# Out:
# At cross fold 2 the cv score is 0.7503560636913622 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# At cross fold 3 the cv score is 0.7482545829660007 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# At cross fold 4 the cv score is 0.7460626195589475 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# At cross fold 5 the cv score is 0.7503037056541191 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# At cross fold 6 the cv score is 0.7480181925972896 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# At cross fold 7 the cv score is 0.7473469328379879 and accuracy score for traing is 0.745043941582245 and accuracy for the tsting is 0.7755982423704892
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.scatter(x=y_test,y=pred_test,color='y')
plt.plot(y_test,y_test,color='r')
plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Refression',fontsize=18)
plt.show()

# %% [markdown]
# # REGULARIZATION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.metrics import r2_score
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
rdg=Ridge(alpha=0.0001,random_state=45)
rdg.fit(x_train,y_train)
rdg.score(x_train,y_train)
# Out:
# 0.7450439415819883

# %%
clf.score(x_train,y_train)
# Out:
# 0.7450342702966595

# %%
#final model training
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training = ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 74.50438448747686

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 77.55940263837562

# %%
cv_score=cross_val_score(ls,x,y,cv=4)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 74.60617468782273

# %% [markdown]
# # ENSEMBLE

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}

rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)

clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion="mae",max_features="log2")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)

rf_score=r2_score(y_test,pred_decision)
print('R2_score:',rf_score*100)

rf_score2=cross_val_score(rf,x,y,cv=5)
rfc=rf_score2.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2_score: 87.01176324020821
# Cross Val Score: 83.92174074472169

# %% [markdown]
# Accuracy is 87%
#
# Cross validation score is 84%

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.scatter(x=y_test,y=pred_decision,color='y')
plt.plot(y_test,y_test,color='r')
plt.xlabel('Actual Charges',fontsize=14)
plt.ylabel('Predicted charges',fontsize=14)
plt.title('Linear Refression',fontsize=18)
plt.show()

# %%
#saving to obj
import joblib
joblib.dump(rf_score,'Medical_Insurance_Cost.obj')
# Out:
# ['Medical_Insurance_Cost.obj']
